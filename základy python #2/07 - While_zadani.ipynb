# %% [markdown]
# # Desetiminutovka
# Napiš program, který:
#
# Vytvoří seznam pro oblíbené filmy, kde již při vzniku budou natvrdo napsané filmy: Matrix, Logan.
#
# * Poté se zeptá uživatele 3× na název filmu a každý přidá do seznamu.
# * Poté vypíše všechny filmy v seznamu pomocí for cyklu.
# * Nakonec vypíše, kolik filmů je v seznamu.
# ---
#
# Ukázka řešení:
# ```
# Zadej název filmu: Inception
# Zadej název filmu: Avatar 2
# Zadej název filmu: Titanic
#
# Tvoje oblíbené filmy jsou:
# Matrix
# Logan
# Inception
# Avatar 2
# Titanic
#
# Celkem filmů: 5
# ```

# %%
lista = ["Matrix", "Logan"]
for i in range (3):
    x = (input("Zadej název filmu"))
    lista.append(x)
print(f"nej film je: {list}")
print("celkem je: ", len(lista))
# Out:
# nej film je: ['Matrix', 'Logan', 0, 1, 2]
# celkem je:  5

# %% [markdown]
# # Cyklus `while`
#
# ## Co je to cyklus?
#
# Cyklus (anglicky *loop*) je základní programátorská konstrukce, která umožňuje **opakovaně vykonávat blok kódu**. Místo toho, abychom stejný kód psali znovu a znovu, zapíšeme jej jednou a necháme ho opakovat automaticky.
#
# V Pythonu existují dva hlavní typy cyklů:
#
# | Cyklus | Kdy ho použít |
# |--------|--------------|
# | `for` | Když **předem víme**, kolikrát se má kód opakovat (nebo procházíme kolekci) |
# | `while` | Když **předem nevíme**, kolikrát se má kód opakovat – opakujeme **dokud platí podmínka** |
#
# ## Proč potřebujeme `while`?
#
# Představte si tyto situace:
# - Hra běží, **dokud** hráč neprohraje
# - Program se ptá na heslo, **dokud** uživatel nezadá správné
# - Číslo dělíme dvěma, **dokud** je větší než 1
#
# Ve všech těchto případech nevíme předem, kolik opakování bude potřeba — záleží na okolnostech za běhu programu. Přesně na to slouží `while`.

# %% [markdown]
# ## Syntaxe (jak se to píše)
#
# ```python
# while podmínka:
#     příkaz_1
#     příkaz_2
#     příkaz_3
#
# příkaz_mimo_while
# ```
#
# **Klíčové body:**
# - Za klíčovým slovem `while` následuje **podmínka** (logický výraz, stejně jako u `if`)
# - Za podmínkou musí být **dvojtečka** `:`
# - Tělo cyklu (příkazy uvnitř) musí být **odsazené** (standardně 4 mezery)
# - Příkazy na stejné úrovni odsazení jako `while` už **nejsou součástí cyklu**

# %% [markdown]
# ## Sémantika (jak to funguje)
#
# Průběh `while` cyklu krok po kroku:
#
# 1. **Vyhodnoť podmínku** → výsledek je `True` nebo `False`
# 2. Pokud je podmínka **`True`** → proveď všechny příkazy v těle cyklu, pak **se vrať na krok 1**
# 3. Pokud je podmínka **`False`** → **přeskoč** tělo cyklu a pokračuj příkazem za cyklem
#
# ### Vizuální schéma
#
# ```
#         ┌──────────────────┐
#         │  Vyhodnoť podmínku│
#         └────────┬─────────┘
#                  │
#            ┌─────▼─────┐
#            │  True?     │───── NE ────► Pokračuj za cyklem
#            └─────┬──────┘
#                  │ ANO
#            ┌─────▼──────┐
#            │ Proveď tělo │
#            │   cyklu     │
#            └─────┬──────┘
#                  │
#                  └──────────────► (zpět na vyhodnocení podmínky)
# ```
#
# > **Důležité:** Podmínka se kontroluje **vždy na začátku** každého průchodu. Pokud je podmínka `False` hned na začátku, tělo cyklu se **neprovede ani jednou**.

# %% [markdown]
# ## Jednoduché příklady
#
# ### Příklad 1: Odpočítávání
# Jednoduchý odpočet od 5 do 1:

# %%
pocitadlo = 5                    # počáteční hodnota
while pocitadlo > 0:             # opakuj, dokud je počítadlo kladné
    print(pocitadlo)             # vypiš aktuální hodnotu
    pocitadlo = pocitadlo - 1    # sniž hodnotu o 1 (KLÍČOVÉ — bez tohoto by cyklus nikdy neskončil!)
print("Start! 🚀")
# Out:
# Počáteční hodnota: 5
# Další krok: 16
# Další krok: 8
# Další krok: 4
# Další krok: 2
# Další krok: 1
# Konec

# %% [markdown]
# ### Příklad 2: Sčítání čísel od uživatele
#
# Program se opakovaně ptá na číslo a přičítá ho k součtu. Skončí, když uživatel zadá 0:

# %%
soucet = 0
cislo = int(input("Zadej číslo (0 = konec): "))

while cislo != 0:
    soucet = soucet + cislo
    cislo = int(input("Zadej číslo (0 = konec): "))

print(f"Součet všech zadaných čísel: {soucet}")

# %% [markdown]
# ### Příklad 3: Collatzův problém (3n+1)
#
# Slavný matematický problém — vezmeme libovolné přirozené číslo a opakujeme:
# - je-li **sudé**, vydělíme ho dvěma
# - je-li **liché**, vynásobíme třemi a přičteme jedna
#
# Hypotéza říká, že **vždy nakonec dojdeme k číslu 1** (nikdo to zatím nedokázal dokázat ani vyvrátit!).
#
# Více na [Wikipedii](https://cs.wikipedia.org/wiki/Collatz%C5%AFv_probl%C3%A9m).

# %%
x = 6
print("Počáteční hodnota:", x)

while x > 1:                    # opakuj, dokud jsme nedosáhli jedničky
    if x % 2 == 0:              # sudé číslo → vyděl dvěma
        x = x // 2
    else:                        # liché číslo → vynásob 3 a přičti 1
        x = 3 * x + 1
    print("→", x)

print("Hotovo! Došli jsme k 1.")

# %% [markdown]
# ---
#
# # Důležité detaily a časté chyby
#
# ## 1. Klíčové slovo `pass`
#
# Uvnitř těla cyklu musí být vždy **alespoň jeden příkaz**. Pokud chceme cyklus zatím nechat prázdný (jako zástupný kód), použijeme klíčové slovo `pass`:
#
# ```python
# while podminka:
#     pass    # nic nedělej — jen zástupný příkaz (v budoucnu tu něco bude, ale zatím nevím co)
# ```
#
# ## 2. Nekonečný cyklus ⚠️
#
# **Nejčastější chyba při práci s `while`!**
#
# Pokud se podmínka **nikdy nestane `False`**, cyklus poběží donekonečna a program "zamrzne":
#
# ```python
# # ❌ ŠPATNĚ — nekonečný cyklus!
# x = 0
# while x < 10:
#     print(x)
#     # Chybí: x = x + 1  → x je pořád 0, podmínka je pořád True
# ```
#
# **Jak se tomu vyhnout:**
# - Vždy se ujistěte, že **v těle cyklu měníte proměnnou**, která je v podmínce
# - Ověřte, že se hodnota proměnné **postupně přibližuje** k nesplnění podmínky
#
# > 💡 **Tip:** Pokud vám program "zamrzne" — pravděpodobně jste vytvořili nekonečný cyklus. V Jupyter notebooku můžete buňku zastavit tlačítkem stop (⏹), v terminálu kombinací `Ctrl + C`.
#
# ## 3. Podmínka se kontroluje PŘED průchodem
#
# Pokud je podmínka `False` hned na začátku, tělo cyklu se **neprovede ani jednou**:
#
# ```python
# x = 100
# while x < 10:      # 100 < 10 je False → tělo se přeskočí
#     print(x)
#     x = x + 1
# print("Konec")      # Vypíše se rovnou "Konec"
# ```
#
# ## 4. Zkrácený zápis operací
#
# Při práci s cykly často měníme hodnotu proměnné. Python nabízí zkrácené operátory:
#
# | Zkrácený zápis | Ekvivalent |
# |----------------|------------|
# | `x += 1` | `x = x + 1` |
# | `x -= 1` | `x = x - 1` |
# | `x *= 2` | `x = x * 2` |
# | `x //= 2` | `x = x // 2` |
#
# Příklad:
# ```python
# pocitadlo = 0
# while pocitadlo < 5:
#     print(pocitadlo)
#     pocitadlo += 1      # totéž jako: pocitadlo = pocitadlo + 1
# ```
#
# ## 5. `while` vs `for` — kdy co použít?
#
# | Situace | Vhodný cyklus | Proč |
# |---------|--------------|------|
# | Projít seznam studentů | `for` | Víme, kolik jich je |
# | Opakovat kód 10× | `for` + `range` | Známe přesný počet |
# | Ptát se na heslo, dokud není správné | `while` | Nevíme kolikrát uživatel chybuje |
# | Hledat číslo splňující podmínku | `while` | Nevíme, kdy ho najdeme |
# | Hra běží, dokud hráč žije | `while` | Délka hry je nepředvídatelná |

# %% [markdown]
# ---
#
# # Cvičení
#
# ## Úkol 1 — Collatzův problém s počítadlem kroků
# Upravte kód níže tak, aby na závěr vytiskl také **počet kroků** (kolikrát prošel cyklem).
#
# **Nápověda:** Vytvořte si proměnnou (např. `kroky`), která se v každém průchodu zvýší o 1.

# %%
x = 5
print("Počáteční hodnota:", x)

while x > 1:
    if x % 2 == 0:
        x = x // 2
    else:
        x = 3 * x + 1
    print("Další krok:", x)

print("Konec")
# Out:
# Počáteční hodnota: 9
# Další krok: 28
# Další krok: 14
# Další krok: 7
# Další krok: 22
# Další krok: 11
# Další krok: 34
# Další krok: 17
# Další krok: 52
# Další krok: 26
# Další krok: 13
# Další krok: 40
# Další krok: 20
# Další krok: 10
# Další krok: 5
# Další krok: 16
# Další krok: 8
# Další krok: 4
# Další krok: 2
# Další krok: 1
# Konec, Počet kroků: 19

# %% [markdown]
# <details>
# <summary>📋 Výsledky pro kontrolu (klikni pro zobrazení) — referenční řešení má 11 řádků</summary>
#
# | x = 5 | x = 1 | x = 17 | x = 9 |
# |-------|-------|--------|-------|
# | Počáteční hodnota: 5 | Počáteční hodnota: 1 | Počáteční hodnota: 17 | Počáteční hodnota: 9 |
# | Další krok: 16 | Konec, Počet kroků: 0 | Další krok: 52 | Další krok: 28 |
# | Další krok: 8 | | Další krok: 26 | Další krok: 14 |
# | Další krok: 4 | | Další krok: 13 | Další krok: 7 |
# | Další krok: 2 | | Další krok: 40 | Další krok: 22 |
# | Další krok: 1 | | Další krok: 20 | Další krok: 11 |
# | Konec, Počet kroků: 5 | | Další krok: 10 | Další krok: 34 |
# | | | Další krok: 5 | Další krok: 17 |
# | | | Další krok: 16 | Další krok: 52 |
# | | | Další krok: 8 | Další krok: 26 |
# | | | Další krok: 4 | Další krok: 13 |
# | | | Další krok: 2 | Další krok: 40 |
# | | | Další krok: 1 | Další krok: 20 |
# | | | Konec, Počet kroků: 12 | Další krok: 10 |
# | | | | Další krok: 5 |
# | | | | Další krok: 16 |
# | | | | Další krok: 8 |
# | | | | Další krok: 4 |
# | | | | Další krok: 2 |
# | | | | Další krok: 1 |
# | | | | Konec, Počet kroků: 19 |
#
# </details>

# %% [markdown]
# ## Úkol 2 — Výpis čísel od 5 do 11
#
# Vypište pomocí `while` čísla od **5 do 11 včetně** (každé na nový řádek).
#
# > 📝 *Poznámka: Na takový úkol existuje v Pythonu elegantnější způsob pomocí `for` a `range()`, berte to jako trénink práce s `while`.*

# %%
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %% [markdown]
# <details>
# <summary>📋 Výsledky pro kontrolu (klikni pro zobrazení) — referenční řešení má 4 řádky</summary>
#
# ```
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# ```
#
# </details>

# %% [markdown]
# ## Úkol 3 — Čísla mezi dvěma hodnotami
#
# Vypište pomocí `while` všechna celá čísla **mezi** hodnotami uloženými ve dvou proměnných (krajní hodnoty nevypisujte).
#
# Program musí fungovat správně i pokud je první číslo větší než druhé!
#
# > 📝 *Poznámka: Na takový úkol existuje elegantnější řešení pomocí `for`, berte to jako trénink.*
#
# **Nápověda:** Zjistěte, které číslo je menší a které větší (vzpomeňte na `min()` a `max()`).

# %%
# Out:
# Čísla mezi 4 a -2 jsou:
# -1
# 0
# 1
# 2
# 3

# %% [markdown]
# <details>
# <summary>📋 Výsledky pro kontrolu (klikni pro zobrazení) — referenční řešení má 9 řádků</summary>
#
# **a = 4, b = 7:**
# ```
# Čísla mezi 4 a 7 jsou:
# 5
# 6
# ```
#
# **a = -5, b = -1:**
# ```
# Čísla mezi -5 a -1 jsou:
# -4
# -3
# -2
# ```
#
# **a = 4, b = -2 (pozor — první je větší):**
# ```
# Čísla mezi 4 a -2 jsou:
# -1
# 0
# 1
# 2
# 3
# ```
#
# **a = 6, b = 6:**
# ```
# Čísla mezi 6 a 6 jsou:
# ```
# *(žádné číslo — hodnoty jsou stejné)*
#
# </details>

# %% [markdown]
# ## Úkol 4 — Opakovaný vstup od uživatele
#
# Nechte uživatele opakovaně zadávat text. Program vždy vypíše, co uživatel zadal. Pokud uživatel zadá písmeno **`k`**, program skončí.
#
# Toto je **typický vzor** pro `while` — interakce s uživatelem, kde nevíme, kdy skončí.

# %% [markdown]
# <details>
# <summary>📋 Výsledky pro kontrolu (klikni pro zobrazení) — referenční řešení má 5 řádků</summary>
#
# **Příklad 1:**
# ```
# Napiš něco: a
# Zadal jsi: a
# Napiš něco: Ahoj
# Zadal jsi: Ahoj
# Napiš něco: 5
# Zadal jsi: 5
# Napiš něco: k
# Zadal jsi: k
# Konec
# ```
#
# **Příklad 2 (rovnou "k"):**
# ```
# Napiš něco: k
# Zadal jsi: k
# Konec
# ```
#
# **Příklad 3:**
# ```
# Napiš něco: nic
# Zadal jsi: nic
# Napiš něco: 789
# Zadal jsi: 789
# Napiš něco: k
# Zadal jsi: k
# Konec
# ```
#
# </details>

# %% [markdown]
# ## Úkol 5 — Dvě lichá čísla
#
# Nechte uživatele zadávat dvě celá čísla oddělená mezerou. Pokud jsou **obě čísla lichá**, program skončí. Pokud ne, nechá uživatele zadání opakovat.
#
# **Nápověda:**
# - Text od uživatele rozdělíte pomocí `.split()` → vrátí seznam řetězců
# - Liché číslo poznáte pomocí operátoru modulo: `cislo % 2 != 0`

# %%
# TODO poslední úkol je celý na vás

# %% [markdown]
# <details>
# <summary>📋 Výsledky pro kontrolu (klikni pro zobrazení) — referenční řešení má 7 řádků</summary>
#
# ```
# Zadej dvě lichá čísla oddělená mezerou: 4 7
# Zadal jsi 4 a 7, ty nejsou obě lichá
# Zadej dvě lichá čísla oddělená mezerou: 6 4
# Zadal jsi 6 a 4, ty nejsou obě lichá
# Zadej dvě lichá čísla oddělená mezerou: 9 2
# Zadal jsi 9 a 2, ty nejsou obě lichá
# Zadej dvě lichá čísla oddělená mezerou: 1 3
# Zadal jsi 1 a 3, ty jsou obě lichá
# Konec
# ```
#
# </details>
#
# ---
