# %% [markdown]
# # Cvičení 1 — Kalkulačka
#
# * Vytvořte program, který se opakovaně ptá na matematickou operaci (sčítání, odčítání, násobení, dělení).
# * Po výběru operace uživatel zadá 2 čísla a program vypíše výsledek ve formátu `5 + 3 = 8`.
# * Po každém výpočtu se program zeptá, zda chcete pokračovat, nebo skončit klávesou `E`.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zvolte operaci (+, -, *, /): +
# Zadejte první číslo: 5
# Zadejte druhé číslo: 3
# 5 + 3 = 8
# Chcete pokračovat? (E = konec): E
# ```
#
# </details>

# %% [markdown]
# # Cvičení 2 — Malá násobilka
#
# * Vytvořte program, který se zeptá na číslo a vypíše jeho malou násobilku (0–10).
# * Formát výpisu: `5 x 3 = 15`
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte číslo: 5
# 5 x 0 = 0
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# ```
#
# </details>

# %%
#TODO

# %% [markdown]
# # Cvičení 3 — Pyramida čísel
#
# * Program se zeptá na číslo od 1 do 10.
# * Vypíše, zda je číslo sudé nebo liché.
# * Vykreslí pyramidu čísel (viz očekávaný výstup).
# * Vypíše součet všech čísel v pyramidě.
# * Vypíše datový typ proměnné se součtem.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte číslo od 1 do 10: 3
# Zadané číslo je liché
# 1
# 12
# 123
# Výsledná suma pyramidy je: 10
# Suma je datového typu: <class 'int'>
# ```
#
# </details>

# %%
#TODO

# %% [markdown]
# # Cvičení 4 — Mocnitel
#
# * Vytvořte funkci `umocni(cislo)`, která vrátí druhou mocninu zadaného desetinného čísla.
# * Výsledek vypište do konzole.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte číslo: 3.5
# Druhá mocnina čísla 3.5 je 12.25
# ```
#
# </details>

# %%
#TODO
# Out:
# Zadejte číslo: 5
# Číslo 5.0 je umocněno a jeho výsledek je: 25.0

# %%
#TODO

# %% [markdown]
# # Cvičení 5 — Pyramida
#
# * Vytvořte dvě pyramidy podle ukázky — jednu číselnou a jednu znakovou.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# 1
# 12
# 123
# 12
# 1
#
# ###
# ##
# #
# #
# ##
# ###
# ```
#
# </details>

# %%
#TODO

# %%
#TODO

# %% [markdown]
# # Cvičení 6 — Nekonečný cyklus
#
# * Program se opakovaně ptá na číslo.
# * Po zadání čísla `0` vypíše „Nekonečný cyklus skončil“ a skončí.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte číslo jiné než nulu: 5
# zadali jste číslo 5
# Zadejte číslo jiné než nulu: -6
# zadali jste číslo -6
# Zadejte číslo jiné než nulu: 0
# zadali jste číslo 0
# ```
#
# </details>

# %%
#TODO

# %% [markdown]
# # Cvičení 7 — Číselné pole
#
# * Vytvořte pole 5 náhodných čísel (0–50).
# * Vypište pole, jeho sumu, průměr, minimum, maximum a seřazenou verzi. (pro tyto výpočty nepoužijte žádnou funkci)
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# [1, 3, 5, 2, 6]
# 17
# 3.4
# 1
# 6
# [1, 2, 3, 5, 6]
#
# ```
#
# </details>

# %%
#TODO

# %% [markdown]
# # Cvičení 8 — While možnosti
#
# * Program opakovaně nabízí menu s volbami:
#   1. Součet dvou zadaných čísel
#   2. Dělení dvou zadaných čísel
#   3. Spojení textu — pevný text „Dnes je krásné “ se spojí s vaším textem a vypíše se tolikrát, kolik zadáte\n* Jakákoli jiná volba program ukončí.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte
#     číslo 1 pro součet
#     číslo 2 pro dělení
#     číslo 3 pro spojení dvou textů
#     cokoli jiného pro konec
#     :1
# Zadejte první číslo: 5
# Zadejte druhé číslo: 6
# 5 + 6 = 11
# Zadejte
#     číslo 1 pro součet
#     číslo 2 pro dělení
#     číslo 3 pro spojení dvou textů
#     cokoli jiného pro konec
#     :2
# Zadejte první číslo: 5
# Zadejte druhé číslo: 3
# 5 / 3 = 1.6666666666666667
# Zadejte
#     číslo 1 pro součet
#     číslo 2 pro dělení
#     číslo 3 pro spojení dvou textů
#     cokoli jiného pro konec
#     :3
# Zadejte druhý text: počasí
# Dnes je krásné počasí
# Zadejte
#     číslo 1 pro součet
#     číslo 2 pro dělení
#     číslo 3 pro spojení dvou textů
#     cokoli jiného pro konec
#     :5
# Program skončí, zadali jste špatný znak
# ```
#
# </details>

# %%
#TODO

# %% [markdown]
# # Cvičení 9 — Random číslo
#
# * Vygenerujte náhodné číslo od 1 do 10.
# * Vypište všechna čísla od 3 do 7 a zvlášť všechna lichá čísla do 10.
# * Na konci vypište, do kterých kategorií vaše náhodné číslo patří:
#   * v rozmezí 3–7
#   * liché / sudé
#   * kombinace obou
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# 7
#
# 3
# 4
# 5
# 6
# 7
#
# 1
# 3
# 5
# 7
# 9
#
# náhodné číslo je v rozmezí 3 až 7
# náhodné číslo je  liché
# náhodné číslo je liché a v rozmezí 3 až 7
# ```
#
# </details>

# %%
#TODO
import random

# %% [markdown]
# # Cvičení 10 — 2 pole
#
# * Načtěte od uživatele 5× jméno a průměr známek.
# * Vypište všechny žáky s jejich známkami a celkový průměr třídy.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte jméno: l
# Zadejte známku této osoby: 5
# Zadejte jméno: k
# Zadejte známku této osoby: 4
# Zadejte jméno: j
# Zadejte známku této osoby: 3
# Zadejte jméno: h
# Zadejte známku této osoby: 2
# Zadejte jméno: g
# Zadejte známku této osoby: 1.2
# l  má:  5.0
# k  má:  4.0
# j  má:  3.0
# h  má:  2.0
# g  má:  1.2
# Průměr třídy je: 3.04
# Průměr třídy je: 3.04
# ```
#
# </details>

# %%
# TODO

# %% [markdown]
# # Cvičení 11 — 2 pole (dictionary)
#
# * Upravte předchozí úlohu tak, aby místo dvou polí používala dictionary.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte jméno: l
# Zadejte známku této osoby: 5
# Zadejte jméno: k
# Zadejte známku této osoby: 4
# Zadejte jméno: j
# Zadejte známku této osoby: 3
# Zadejte jméno: h
# Zadejte známku této osoby: 2
# Zadejte jméno: g
# Zadejte známku této osoby: 1.2
# l  má:  5.0
# k  má:  4.0
# j  má:  3.0
# h  má:  2.0
# g  má:  1.2
# Průměr třídy je: 3.04
# ```
#
# </details>

# %%
# TODO

# %% [markdown]
# # Cvičení 12 — 2D pole (matice)
#
# * Podle obrázku níže vytvořte 2D pole (matici).
# * Vypočítejte sumu a průměr všech prvků.
#
# # ![image.png](data:image/png;base64,...)
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# 5 4 3 5 4 6
# 2 3 5 4 1 7
# 2 3 6 4 8 9
# Suma je: 81
# Průměr je: 4.5
# ```
#
# </details>
#
# [def]: data:image/png;base64,...

# %%
#pole = [[]]#
#pole = ["adam","eva", "vasek"]
#pole = [[1,2,3],[4,5]]
#pole[0][0] = 5
#TODO

# %% [markdown]
# # Cvičení 13 — Generátor hesel
#
# * Heslo musí obsahovat:
#   * alespoň jedno malé písmeno,
#   * alespoň jedno velké písmeno,
#   * alespoň jednu číslici,
#   * alespoň jeden speciální znak (`!@#$%^&*`).
# * Vstup: délka hesla zadaná uživatelem.
# * Výstup: náhodně vygenerované heslo splňující podmínky.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte délku hesla: 12
# Vygenerované heslo: aB3!kL9@mN2#
# ```
#
# </details>

# %%
import random as rand
import numpy as np
#TODO

# %% [markdown]
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Auto značky: opel je velikostně malé a jeho barva je modré
# Auto značky: audi je velikostně střední a jeho barva je žluté
# Auto značky: bmw je velikostně větší a jeho barva je oranžové
# Auto značky: škoda je velikostně velké a jeho barva je červené
# ```
#
# </details>

# %% [markdown]
# # Cvičení 14 — Generátor hesel (funkce)
#
# * Napiš funkci, která vytvoří náhodné heslo dané délky a vrátí ho.
# * Heslo musí obsahovat:
#   * alespoň jedno malé písmeno,
#   * alespoň jedno velké písmeno,
#   * alespoň jednu číslici,
#   * alespoň jeden speciální znak (`!@#$%^&*`).
# * Vstup: délka hesla zadaná uživatelem.
# * Výstup: náhodně vygenerované heslo splňující podmínky.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Zadejte délku hesla pro vygenerování: 12
# K@%%xJ}.1l\7
# ```
#
# </details>

# %%
# Out:
# Zadejte délku hesla pro vygenerování: 12
# K@%%xJ}.1l\7

# %% [markdown]
# # Cvičení 15 — Matice a její transpozice
#
# * Napište funkci `transpozice(matice)`, která transponuje matici (prohodí řádky a sloupce).
# * Napište funkci `printMatice(matice)`, která matici vypíše řádek po řádku.
# * Vstup: `[[1, 2, 3], [4, 5, 6]]`
# * Výstup: `[[1, 4], [2, 5], [3, 6]]`
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Původní matice:
# 1 2 3
# 4 5 6
# Transponovaná matice:
# 1 4
# 2 5
# 3 6
# ```
#
# </details>

# %%
#funkce TODO


matice = [[1, 2, 3], [4, 5, 6]]
transMatice = transpozice(matice)
print("Původní matice: ")
printMatice(matice)
print("Transponovaná matice: ")
printMatice(transMatice)

# %% [markdown]
# # Cvičení 16 — Validace e-mailových adres
#
# * Program načte soubor `emails.txt` a ověří platnost každé e-mailové adresy.
# * Platné uloží do `valid.txt`, neplatné do `invalid.txt`.
# * Podmínky platnosti:
#   * Obsahuje znak `@`.
#   * Po `@` následuje doména s alespoň jednou tečkou.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# dobry@dobry.cz → ✅ platný
# dobry@spatnycz → ❌ neplatný
# dobry.@spatnycz → ❌ neplatný
# dobry@.spatne.cz → ❌ neplatný
#
# ✅ Platné adresy uloženy do 'valid.txt'
# ❌ Neplatné adresy uloženy do 'invalid.txt'
# ```
#
# </details>

# %%
with open("emails.txt","w") as soubor:
    soubor.write("dobry@dobry.cz \ndobry@spatnycz \ndobry.@spatnycz \ndobry@.spatne.cz ") # správně je pouze první email
#TODO

# %% [markdown]
# # Cvičení 17 — Playlist
#
# * Ze zadaného playlistu:
#   * Spočítejte celkovou délku playlistu.
#   * Najděte nejdelší píseň (název a interpret).
#   * Zobrazte seznam unikátních interpretů.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Nejdelší je: ['Bohemian Rhapsody', 'Queen', '05:55']
# Celková délka playlistu je: 25 minut 42 sekund
# Unikatní interpreta jsou: {'Billie Eilish', 'The Weeknd', 'Leonard Cohen', 'Ed Sheeran', 'Queen'}
# ```
#
# </details>

# %%
playlist = [
    ["Shape of You", "Ed Sheeran", "03:54"],
    ["Perfect", "Ed Sheeran", "04:40"],
    ["Blinding Lights", "The Weeknd", "03:20"],
    ["Bohemian Rhapsody", "Queen", "05:55"],
    ["Bad Guy", "Billie Eilish", "03:14"],
    ["Hallelujah", "Leonard Cohen", "04:39"]
]
# Out:
# Nejdelší je: ['Bohemian Rhapsody', 'Queen', '05:55']
# Celková délka playlistu je: 25 minut 42 sekund
# Unikatní interpreta jsou: {'Billie Eilish', 'The Weeknd', 'Leonard Cohen', 'Ed Sheeran', 'Queen'}

# %% [markdown]
# # Cvičení 18 — Caesarova šifra
#
# * Vytvořte program pro Caesarovu šifru s posunem o 5.
# * Zašifrujte a dešifrujte větu `"Ahoj Svete"`.
#
# <details>
# <summary>🔎 Očekávaný výstup (klikni pro zobrazení)</summary>
#
# ```
# Původní text: Ahoj Svete
# Zašifrovaný text: Fmto Xajyj
# Dešifrovaný text: Ahoj Svete
# ```
#
# </details>

# %%
#TODO
